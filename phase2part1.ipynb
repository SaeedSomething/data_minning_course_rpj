# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv("cleaned.csv")
df.describe()
# Out:
#         Unnamed: 0       Rating     Installs       Metric      Reviews  \
# count  6250.000000  6250.000000  6250.000000  6250.000000  6250.000000
# mean   3124.500000     0.831658     0.001764     0.001736     0.001665
# std    1804.363923     0.076868     0.003581     0.003499     0.003214
# min       0.000000     0.580000     0.000000     0.000000     0.000000
# 25%    1562.250000     0.765541     0.000002     0.000002     0.000001
# 50%    3124.500000     0.840868     0.000100     0.000095     0.000043
# 75%    4686.750000     0.890314     0.002000     0.001856     0.000727
# max    6249.000000     1.000000     0.011069     0.010809     0.008571
#
#              Price  minimum income         Size
# count  6250.000000     6250.000000  6250.000000
# mean      0.000182        0.000037     0.019048
# std       0.000738        0.000151     0.014349
# min       0.000000        0.000000     0.000000
# 25%       0.000000        0.000000     0.005990
# 50%       0.000000        0.000000     0.019081
# 75%       0.000000        0.000000     0.025354
# max       0.003176        0.000648     0.063627

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'App', 'App Id', 'Category', 'Content Rating', 'Rating',
#        'Installs', 'Metric', 'Reviews', 'Price', 'Currency', 'minimum income',
#        'Ad Supported', 'In app purchases', 'Size', 'Version', 'Last update',
#        'Released', 'Android version Text', 'Editor Choice', 'Developer Id',
#        'Developer', 'Developer Address', 'RatingCategorized',
#        'InstallsCategorized', 'MetricCategorized', 'ReviewsCategorized',
#        'PriceCategorized', 'minimum incomeCategorized', 'SizeCategorized'],
#       dtype='object')

# %%
df = df.drop(
    columns=[
        "Unnamed: 0",
        "minimum income",
        "minimum incomeCategorized",
    ],
    axis=1,
)

# %%
def show_types(df):
    for col in df.columns:
        print(col, "=", df[col][0], "=", type(df[col][0]))


show_types(df)
# Out:
# App = minecraft = <class 'str'>
# App Id = com.mojang.minecraftp = <class 'str'>
# Category = arcad = <class 'str'>
# Content Rating = everyone 10+ = <class 'str'>
# Rating = 0.9111484 = <class 'numpy.float64'>
# Installs = 0.002 = <class 'numpy.float64'>
# Metric = 0.0046289883201103 = <class 'numpy.float64'>
# Reviews = 0.0085714869305811 = <class 'numpy.float64'>
# Price = 0.0031764456445644 = <class 'numpy.float64'>
# Currency = usd = <class 'str'>
# Ad Supported = True = <class 'numpy.bool_'>
# In app purchases = True = <class 'numpy.bool_'>
# Size = 0.0253542472483757 = <class 'numpy.float64'>
# Version = 1.16.221.01 = <class 'str'>
# Last update = 21-apr-21 = <class 'str'>
# Released = 15-aug-11 = <class 'str'>
# Android version Text = varies with devic = <class 'str'>
# Editor Choice = True = <class 'numpy.bool_'>
# Developer Id = 4.77e+18 = <class 'str'>
# Developer = mojang = <class 'str'>
# Developer Address = mojang
# maria skolgata 83
# 118 53
# stockholm
# sweden = <class 'str'>
# RatingCategorized = Very High = <class 'str'>
# InstallsCategorized = Very Low = <class 'str'>
# MetricCategorized = Medium = <class 'str'>
# ReviewsCategorized = Very High = <class 'str'>
# PriceCategorized = Very High = <class 'str'>
# SizeCategorized = Low = <class 'str'>

# %%
fp_cols = [
    "App",
    "App Id",
    "Category",
    "Content Rating",
    "Currency",
    "Ad Supported",
    "In app purchases",
    "Version",
    "Last update",
    "Released",
    "Android version Text",
    "Editor Choice",
    "Developer",
    "Developer Address",
    "RatingCategorized",
    "InstallsCategorized",
    "MetricCategorized",
    "ReviewsCategorized",
    "PriceCategorized",
    "SizeCategorized",
]

# %%
# apriori doesn't work with numeric data , so we'll keep categorical and bool data only
# and using get_dummies function we'll make it applyable for the apriori function
df = df[fp_cols]
df = pd.get_dummies(df, columns=fp_cols)
df.columns
# Out:
# Index(['App_#name?', 'App_.r', 'App_10 best foods for y',
#        'App_10 wpm amateur ham radio cw morse code train',
#        'App_100 doors of reveng', 'App_101 c programming problem', 'App_11st',
#        'App_1800 contacts - lens stor', 'App_1line – one line with one touch',
#        'App_20 minuten (ch)',
#        ...
#        'ReviewsCategorized_Low', 'ReviewsCategorized_Very High',
#        'ReviewsCategorized_Very Low', 'PriceCategorized_Very High',
#        'PriceCategorized_Very Low', 'SizeCategorized_High',
#        'SizeCategorized_Low', 'SizeCategorized_Medium',
#        'SizeCategorized_Very High', 'SizeCategorized_Very Low'],
#       dtype='object', length=18538)

# %%
min_support = 1
frequent_itemsets = []
while len(frequent_itemsets) < 100:
    min_support -= 0.01

    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    frequent_itemsets = frequent_itemsets[
        frequent_itemsets["itemsets"].apply(lambda x: len(x) >= 2)
    ]
frequent_itemsets = frequent_itemsets.sort_values(by="support", ascending=False)
frequent_itemsets.to_csv("frequent_itemsets.csv")
print(f"Min support = {min_support}")
frequent_itemsets
# Out:
# Min support = 0.7599999999999998
#      support                                           itemsets
# 12   0.98016                  (Currency_usd, Ad Supported_True)
# 18   0.95840           (Editor Choice_False, Ad Supported_True)
# 22   0.94272     (PriceCategorized_Very Low, Ad Supported_True)
# 39   0.93856  (Editor Choice_False, Currency_usd, Ad Support...
# 13   0.93856                (Editor Choice_False, Currency_usd)
# ..       ...                                                ...
# 110  0.76528  (MetricCategorized_Very Low, Ad Supported_True...
# 102  0.76528  (MetricCategorized_Very Low, Ad Supported_True...
# 86   0.76528  (PriceCategorized_Very Low, Editor Choice_Fals...
# 32   0.76400  (ReviewsCategorized_Very Low, PriceCategorized...
# 62   0.76400  (ReviewsCategorized_Very Low, PriceCategorized...
#
# [103 rows x 2 columns]

# %%
minimum_threshold = 1
rules = pd.DataFrame()

while len(rules) < 30:
    minimum_threshold -= 0.01
    rules = association_rules(
        frequent_itemsets,
        metric="lift",
        min_threshold=minimum_threshold,
        support_only=True,
    )
print(f"Min threshhold = {minimum_threshold}")
# Out:
# Min threshhold = 0.8999999999999999

# %%
rules = rules.sort_values(by="support", ascending=False)
rules.to_csv("rules.csv")

# %%
rules
# Out:
#                                          antecedents  \
# 0                                     (Currency_usd)
# 1                                (Ad Supported_True)
# 2                              (Editor Choice_False)
# 3                                (Ad Supported_True)
# 4                        (PriceCategorized_Very Low)
# 5                                (Ad Supported_True)
# 10                                    (Currency_usd)
# 13                                    (Currency_usd)
# 12                             (Editor Choice_False)
# 11                               (Ad Supported_True)
# 9                              (Editor Choice_False)
# 8                  (Currency_usd, Ad Supported_True)
# 7           (Editor Choice_False, Ad Supported_True)
# 6                (Editor Choice_False, Currency_usd)
# 18                 (Currency_usd, Ad Supported_True)
# 21                               (Ad Supported_True)
# 20                                    (Currency_usd)
# 19                       (PriceCategorized_Very Low)
# 15                                    (Currency_usd)
# 17    (PriceCategorized_Very Low, Ad Supported_True)
# 16         (PriceCategorized_Very Low, Currency_usd)
# 14                       (PriceCategorized_Very Low)
# 22                       (PriceCategorized_Very Low)
# 23                             (Editor Choice_False)
# 24  (PriceCategorized_Very Low, Editor Choice_False)
# 25    (PriceCategorized_Very Low, Ad Supported_True)
# 26          (Editor Choice_False, Ad Supported_True)
# 27                       (PriceCategorized_Very Low)
# 28                             (Editor Choice_False)
# 29                               (Ad Supported_True)
#
#                                          consequents  antecedent support  \
# 0                                (Ad Supported_True)                 NaN
# 1                                     (Currency_usd)                 NaN
# 2                                (Ad Supported_True)                 NaN
# 3                              (Editor Choice_False)                 NaN
# 4                                (Ad Supported_True)                 NaN
# 5                        (PriceCategorized_Very Low)                 NaN
# 10          (Editor Choice_False, Ad Supported_True)                 NaN
# 13                             (Editor Choice_False)                 NaN
# 12                                    (Currency_usd)                 NaN
# 11               (Editor Choice_False, Currency_usd)                 NaN
# 9                  (Currency_usd, Ad Supported_True)                 NaN
# 8                              (Editor Choice_False)                 NaN
# 7                                     (Currency_usd)                 NaN
# 6                                (Ad Supported_True)                 NaN
# 18                       (PriceCategorized_Very Low)                 NaN
# 21         (PriceCategorized_Very Low, Currency_usd)                 NaN
# 20    (PriceCategorized_Very Low, Ad Supported_True)                 NaN
# 19                 (Currency_usd, Ad Supported_True)                 NaN
# 15                       (PriceCategorized_Very Low)                 NaN
# 17                                    (Currency_usd)                 NaN
# 16                               (Ad Supported_True)                 NaN
# 14                                    (Currency_usd)                 NaN
# 22                             (Editor Choice_False)                 NaN
# 23                       (PriceCategorized_Very Low)                 NaN
# 24                               (Ad Supported_True)                 NaN
# 25                             (Editor Choice_False)                 NaN
# 26                       (PriceCategorized_Very Low)                 NaN
# 27          (Editor Choice_False, Ad Supported_True)                 NaN
# 28    (PriceCategorized_Very Low, Ad Supported_True)                 NaN
# 29  (PriceCategorized_Very Low, Editor Choice_False)                 NaN
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  NaN  0.98016         NaN   NaN       NaN         NaN
# 1                  NaN  0.98016         NaN   NaN       NaN         NaN
# 2                  NaN  0.95840         NaN   NaN       NaN         NaN
# 3                  NaN  0.95840         NaN   NaN       NaN         NaN
# 4                  NaN  0.94272         NaN   NaN       NaN         NaN
# 5                  NaN  0.94272         NaN   NaN       NaN         NaN
# 10                 NaN  0.93856         NaN   NaN       NaN         NaN
# 13                 NaN  0.93856         NaN   NaN       NaN         NaN
# 12                 NaN  0.93856         NaN   NaN       NaN         NaN
# 11                 NaN  0.93856         NaN   NaN       NaN         NaN
# 9                  NaN  0.93856         NaN   NaN       NaN         NaN
# 8                  NaN  0.93856         NaN   NaN       NaN         NaN
# 7                  NaN  0.93856         NaN   NaN       NaN         NaN
# 6                  NaN  0.93856         NaN   NaN       NaN         NaN
# 18                 NaN  0.92288         NaN   NaN       NaN         NaN
# 21                 NaN  0.92288         NaN   NaN       NaN         NaN
# 20                 NaN  0.92288         NaN   NaN       NaN         NaN
# 19                 NaN  0.92288         NaN   NaN       NaN         NaN
# 15                 NaN  0.92288         NaN   NaN       NaN         NaN
# 17                 NaN  0.92288         NaN   NaN       NaN         NaN
# 16                 NaN  0.92288         NaN   NaN       NaN         NaN
# 14                 NaN  0.92288         NaN   NaN       NaN         NaN
# 22                 NaN  0.90256         NaN   NaN       NaN         NaN
# 23                 NaN  0.90256         NaN   NaN       NaN         NaN
# 24                 NaN  0.90256         NaN   NaN       NaN         NaN
# 25                 NaN  0.90256         NaN   NaN       NaN         NaN
# 26                 NaN  0.90256         NaN   NaN       NaN         NaN
# 27                 NaN  0.90256         NaN   NaN       NaN         NaN
# 28                 NaN  0.90256         NaN   NaN       NaN         NaN
# 29                 NaN  0.90256         NaN   NaN       NaN         NaN
#
#     zhangs_metric
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 10            NaN
# 13            NaN
# 12            NaN
# 11            NaN
# 9             NaN
# 8             NaN
# 7             NaN
# 6             NaN
# 18            NaN
# 21            NaN
# 20            NaN
# 19            NaN
# 15            NaN
# 17            NaN
# 16            NaN
# 14            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
